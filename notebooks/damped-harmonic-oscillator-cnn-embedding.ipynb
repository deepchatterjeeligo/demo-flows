# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# \begin{align}
# \ddot{x}(t) + 2\beta\omega_0\dot{x}(t) + \omega_0^2x(t) = 0
# \end{align}
#
# Ansatz, $x = \exp(\gamma t)$; $\gamma = -\omega_0\left[\beta \pm i\sqrt{1 - \beta^2}\right]$

# %%
def damped_sho(t, omega_0, beta, shift=0):
    # beta less than 1 for underdamped
    envel = beta * omega_0
    osc = np.sqrt(1 - beta**2) * omega_0
    tau = t - shift
    data = np.exp(-envel * tau) * np.cos(osc * tau)
    data[tau < 0] = 0  # assume oscillator starts at tau = 0
    return data

# %% [markdown]
# ## Plot

# %%
omega_0 = 1
beta = 0.3

t_vals = np.linspace(-1, 10, 200)
for shift in [-1, 0, 1, 2]:
    x_vals = damped_sho(t_vals, omega_0=omega_0, beta=beta, shift=shift)
    plt.plot(t_vals, x_vals, label=f"{omega_0=}; {beta=}; {shift=}")
plt.xlabel("Time")
plt.ylabel("Disp")
plt.axvline(x=0, linestyle='dotted', color='black')
plt.legend()

# %%
injection_parameters = dict(omega_0=omega_0, beta=beta, shift=2)

# %%
num_points = 200
t_vals = np.linspace(-1, 10, num_points)

# %%
sigma = 0.05

# %%
data = damped_sho(t_vals, **injection_parameters) + np.random.normal(0, sigma, t_vals.size)

# %%
fig, ax = plt.subplots()
ax.plot(t_vals, data, 'o', label='$\\{x_i, y_i\\}$')
ax.plot(t_vals, damped_sho(t_vals, **injection_parameters), '--r', label='f(x)')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
import bilby
from bilby.core.prior import Uniform, DeltaFunction

# %% [markdown]
# ## Prior for parameters

# %%
priors = dict()

priors['omega_0'] = Uniform(0.1, 2, name='omega_0', latex_label='$\omega_0$')
priors['beta'] = Uniform(0, 0.5, name='beta', latex_label='$\\beta$')
priors['shift'] = Uniform(-4, 4, name='shift', latex_label='$\Delta\;t$')

# %% [markdown]
# ## Likelihood

# %%
# from bilby.core.likelihood import GaussianLikelihood

# log_l = GaussianLikelihood(t_vals, data, damped_sho, sigma=sigma)

# %%
# result = bilby.run_sampler(
#     likelihood=log_l, priors=priors, sampler='dynesty',
#     nlive=300, npool=4, save=False, clean=True,
#     injection_parameters=injection_parameters,
#     outdir='./damped_sho',
#     label='damped_sho'
# )

# %%
# result.plot_corner(priors=True)

# %% [markdown]
# # Train embedding space first
#
# The aim is to make the network be agnostic to shift in time. Train embedding space to cluster shifts in intercept value.

# %%
from IPython.display import clear_output
from time import sleep

# %%
def get_data(omega_0=None, beta=None, shift=None, num_points=1):
    """Sample omega, beta, shift and return a batch of data with noise"""
    omega_0 = priors['omega_0'].sample() if omega_0 is None else omega_0
    beta = priors['beta'].sample() if beta is None else beta
    shift = priors['shift'].sample() if shift is None else shift
    t_vals = np.linspace(-1, 10, num_points)
    y = damped_sho(t_vals, omega_0=omega_0, beta=beta, shift=shift)
    y += sigma*np.random.normal(size=y.size)

    return t_vals, y, omega_0, beta, shift

# %% [markdown]
# # Add augmentation

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch import nn, optim
from torch.utils.tensorboard import SummaryWriter

# %%
num_simulations = 10000
theta_vals = []
data_vals = []
for ii in range(num_simulations):
    t_vals, y, omega, beta, shift = get_data(num_points=200, shift=0)
    data_vals.append(y)
    theta_vals.append([omega, beta, shift])

# %%
theta_vals = np.array(theta_vals)
data_vals = np.array(data_vals)

# %%
theta_vals[0]
# Out:
# array([1.69200676, 0.03106254, 0.        ])

# %%
class DataGenerator(Dataset):
    def __len__(self):
        return num_simulations

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        # augment the data to have several shifted intercepts
        theta, data_aug, data_orig = self.augment(idx)

        return (
            torch.from_numpy(theta).to(torch.float32),
            torch.from_numpy(data_aug).to(torch.float32),
            torch.from_numpy(data_orig).to(torch.float32)
        )

    def augment(self, idx):
        repeats = 30  # just a choice, can be different
        omega = theta_vals[idx][0]
        beta = theta_vals[idx][1]
        theta_aug_vals, data_aug_vals, data_orig_vals = [], [], []
        for _ in range(repeats):
            # reproduce every instance with zero shifts
            t_val, y_val_orig, omega_0, beta, shift = get_data(
                omega_0=omega, beta=beta, shift=0,
                num_points=num_points
            )
            data_orig_vals.append(y_val_orig)
            # augment every instance of natural freq and damping with several shifts
            t_val, y_val, omega_0, beta, shift = get_data(
                omega_0=omega, beta=beta, shift=None,
                num_points=num_points
            )
            data_aug_vals.append(y_val)

            theta_aug_vals.append([omega_0, beta, shift])
        return np.array(theta_aug_vals), np.array(data_aug_vals), np.array(data_orig_vals)

# %%
dataset = DataGenerator()

# %%
dataset[0][1].shape
# Out:
# torch.Size([30, 200])

# %%
t, d, _ = dataset.augment(4)

fig, ax = plt.subplots()

for (omega, beta, shift), points in zip(t, d):
    ax.plot(t_vals, points, 'o', markersize=0.8, label='$\\{x_i, y_i\\}$')
ax.set_xlabel('t')
ax.set_ylabel('y')
ax.set_title(f"Augmented sample; Omega_0 = {t[0][0]:.1f}; Beta = {t[0][1]:.1f}")
# Out:
# Text(0.5, 1.0, 'Augmented sample; Omega_0 = 1.9; Beta = 0.0')

# %%
train_set_size = int(0.8 * num_simulations)
val_set_size = int(0.1 * num_simulations)
test_set_size = int(0.1 * num_simulations)

train_data, val_data, test_data = torch.utils.data.random_split(
    dataset, [train_set_size, val_set_size, test_set_size])

# %%
TRAIN_BATCH_SIZE = 200
VAL_BATCH_SIZE = 50

train_data_loader = DataLoader(
    train_data, batch_size=TRAIN_BATCH_SIZE,
    shuffle=True
)

val_data_loader = DataLoader(
    val_data, batch_size=VAL_BATCH_SIZE,
    shuffle=True
)

test_data_loader = DataLoader(
    test_data, batch_size=1,
    shuffle=False
)

# %%
for theta, data_aug, data_orig in train_data_loader:
    break

# %%
theta.shape, data_aug.shape
# Out:
# (torch.Size([200, 30, 3]), torch.Size([200, 30, 200]))

# %% [markdown]
# ## Define similarity loss

# %%
# implemented from https://github.com/violatingcp/codec
class VICRegLoss(nn.Module):
    def __init__(self, lambda_param=1, mu_param=1,
                 nu_param=20, sort_tolerance=1.0,
                 sort_reg='l2'):
        
        super().__init__()
        self.lambda_param = lambda_param
        self.mu_param = mu_param
        self.nu_param = nu_param
        self.tolerance = sort_tolerance
        self.reg = sort_reg

    def forward(self, x, y):
        repr_loss = F.mse_loss(x, y)

        x = x - x.mean(dim=0)
        y = y - y.mean(dim=0)
        N = x.size(0)
        D = x.size(1)
        
        std_x = torch.sqrt(x.var(dim=0) + 0.0001)
        std_y = torch.sqrt(y.var(dim=0) + 0.0001)
        std_loss = torch.mean(F.relu(1 - std_x)) / 2 + torch.mean(F.relu(1 - std_y)) / 2

        x = (x-x.mean(dim=0))/x.std(dim=0)
        y = (y-y.mean(dim=0))/y.std(dim=0)

        # transpose dims 1 and 2; keep batch dim i.e. 0, unchanged
        cov_x = (x.transpose(1, 2) @ x) / (N - 1)
        cov_y = (y.transpose(1, 2) @ y) / (N - 1)
        cov_loss = self.off_diagonal(cov_x).pow_(2).sum().div(D)
        cov_loss += self.off_diagonal(cov_y).pow_(2).sum().div(D)

        return repr_loss + 3*cov_loss + 5*std_loss

    def off_diagonal(self,x):
        num_batch, n, m = x.shape
        assert n == m
        # All off diagonal elements from complete batch flattened
        return x.flatten(start_dim=1)[...,:-1].view(num_batch, n - 1, n + 1)[...,1:].flatten()

# %%
vicreg_loss = VICRegLoss()

# %%
class SimilarityEmbedding(nn.Module):
    """Simple Conv embedding"""
    def __init__(self, num_hidden_layers=1, activation=torch.relu):
        super().__init__()
        self.num_hidden_layers = num_hidden_layers
        self.conv_layer = nn.Conv1d(30, 30, 3, padding='same')

        self.final_layer_1 = nn.Linear(200, 10)
        self.final_layer_2 = nn.Linear(10, 4)
        self.activation = activation

    def forward(self, x):
        x = self.conv_layer(x)
        x = self.activation(x)
        x = self.final_layer_1(x)
        x = self.activation(x)
        x = self.final_layer_2(x)
        return x

# %%
similarity_embedding = SimilarityEmbedding(num_hidden_layers=1)

optimizer = optim.Adam(similarity_embedding.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98)

# %%
similarity_embedding(data_aug).shape
# Out:
# torch.Size([200, 30, 4])

# %%
similarity_embedding_model_path = './sho_similarity_embedding_cnn.pt'
# torch.save(similarity_embedding.state_dict(), similarity_embedding_model_path)
similarity_embedding.load_state_dict(torch.load(similarity_embedding_model_path))

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_sim_loss = 0.
    last_sim_loss = 0.

    for idx, val in enumerate(train_data_loader, 1):
        augmented_theta, augmented_data, unshifted_data = val
        embedded_values_aug = similarity_embedding(augmented_data)
        embedded_values_orig = similarity_embedding(unshifted_data)

        similar_embedding_loss = vicreg_loss(
            embedded_values_aug,
            embedded_values_orig
        )
        #similar_embedding_loss /= TRAIN_BATCH_SIZE

        optimizer.zero_grad()
        similar_embedding_loss.backward()
        optimizer.step()
        # Gather data and report
        running_sim_loss += similar_embedding_loss.item()
        if idx % 10 == 0:
            last_sim_loss = running_sim_loss / 10
            print(' Avg. train loss/batch after {} batches = {:.4f}'.format(idx, last_sim_loss))
            tb_x = epoch_index * len(train_data_loader) + idx
            tb_writer.add_scalar('SimLoss/train', last_sim_loss, tb_x)
            running_sim_loss = 0.
    return last_sim_loss


def val_one_epoch(epoch_index, tb_writer):
    running_sim_loss = 0.
    last_sim_loss = 0.

    for idx, val in enumerate(val_data_loader, 1):
        augmented_theta, augmented_data, unshifted_data = val
        embedded_values_aug = similarity_embedding(augmented_data)
        embedded_values_orig = similarity_embedding(unshifted_data)

        similar_embedding_loss =vicreg_loss(
            embedded_values_aug,
            embedded_values_orig
        )
        #similar_embedding_loss /= VAL_BATCH_SIZE

        running_sim_loss += similar_embedding_loss.item()
        if idx % 10 == 0:
            last_sim_loss = running_sim_loss / 10
            tb_x = epoch_index * len(val_data_loader) + idx + 1
            tb_writer.add_scalar('SimLoss/val', last_sim_loss, tb_x)
            tb_writer.flush()
            running_sim_loss = 0.
    tb_writer.flush()
    return last_sim_loss

# %%
writer = SummaryWriter("sho_embedding_cnn", comment="Similarity with LR=1e-3", flush_secs=5)
epoch_number = 0

# %%
# %%time
# UNCOMMENT AND RUN TO TRAIN FROM SCRATCH
EPOCHS = 50

for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))
    # Gradient tracking
    similarity_embedding.train(True)
    avg_train_loss = train_one_epoch(epoch_number, writer)
    
    # no gradient tracking, for validation
    similarity_embedding.train(False)
    avg_val_loss = val_one_epoch(epoch_number, writer)
    
    print(f"Train/Val Sim Loss after epoch: {avg_train_loss:.4f}/{avg_val_loss:.4f}")

    epoch_number += 1
    scheduler.step()
# Out:
# EPOCH 51:
#  Avg. train loss/batch after 10 batches = 2.3267
#  Avg. train loss/batch after 20 batches = 2.3199
#  Avg. train loss/batch after 30 batches = 2.3025
#  Avg. train loss/batch after 40 batches = 2.3374
# Train/Val Sim Loss after epoch: 2.3374/3.8024
# EPOCH 52:
#  Avg. train loss/batch after 10 batches = 2.3088
#  Avg. train loss/batch after 20 batches = 2.3243
#  Avg. train loss/batch after 30 batches = 2.3209
#  Avg. train loss/batch after 40 batches = 2.3096
# Train/Val Sim Loss after epoch: 2.3096/3.8004
# EPOCH 53:
#  Avg. train loss/batch after 10 batches = 2.3111
#  Avg. train loss/batch after 20 batches = 2.2998
#  Avg. train loss/batch after 30 batches = 2.3118
#  Avg. train loss/batch after 40 batches = 2.3071
# Train/Val Sim Loss after epoch: 2.3071/3.5688
# EPOCH 54:
#  Avg. train loss/batch after 10 batches = 2.3104
#  Avg. train loss/batch after 20 batches = 2.3043
#  Avg. train loss/batch after 30 batches = 2.2940
#  Avg. train loss/batch after 40 batches = 2.3094
# Train/Val Sim Loss after epoch: 2.3094/3.6047
# EPOCH 55:
#  Avg. train loss/batch after 10 batches = 2.2701
#  Avg. train loss/batch after 20 batches = 2.3009
#  Avg. train loss/batch after 30 batches = 2.2772
#  Avg. train loss/batch after 40 batches = 2.2668
# Train/Val Sim Loss after epoch: 2.2668/3.7198
# EPOCH 56:
#  Avg. train loss/batch after 10 batches = 2.2749
#  Avg. train loss/batch after 20 batches = 2.2458
#  Avg. train loss/batch after 30 batches = 2.2679
#  Avg. train loss/batch after 40 batches = 2.2421
# Train/Val Sim Loss after epoch: 2.2421/3.6026
# EPOCH 57:
#  Avg. train loss/batch after 10 batches = 2.2568
#  Avg. train loss/batch after 20 batches = 2.2345
#  Avg. train loss/batch after 30 batches = 2.2603
#  Avg. train loss/batch after 40 batches = 2.2849
# Train/Val Sim Loss after epoch: 2.2849/3.8073
# EPOCH 58:
#  Avg. train loss/batch after 10 batches = 2.2462
#  Avg. train loss/batch after 20 batches = 2.2351
#  Avg. train loss/batch after 30 batches = 2.2341
#  Avg. train loss/batch after 40 batches = 2.2367
# Train/Val Sim Loss after epoch: 2.2367/3.6516
# EPOCH 59:
#  Avg. train loss/batch after 10 batches = 2.2437
#  Avg. train loss/batch after 20 batches = 2.2542
#  Avg. train loss/batch after 30 batches = 2.2561
#  Avg. train loss/batch after 40 batches = 2.2513
# Train/Val Sim Loss after epoch: 2.2513/3.9466
# EPOCH 60:
#  Avg. train loss/batch after 10 batches = 2.2423
#  Avg. train loss/batch after 20 batches = 2.2108
#  Avg. train loss/batch after 30 batches = 2.2527
#  Avg. train loss/batch after 40 batches = 2.2246
# Train/Val Sim Loss after epoch: 2.2246/3.7418
# EPOCH 61:
#  Avg. train loss/batch after 10 batches = 2.2170
#  Avg. train loss/batch after 20 batches = 2.2091
#  Avg. train loss/batch after 30 batches = 2.2239
#  Avg. train loss/batch after 40 batches = 2.2068
# Train/Val Sim Loss after epoch: 2.2068/3.5383
# EPOCH 62:
#  Avg. train loss/batch after 10 batches = 2.1960
#  Avg. train loss/batch after 20 batches = 2.2225
#  Avg. train loss/batch after 30 batches = 2.2154
#  Avg. train loss/batch after 40 batches = 2.2168
# Train/Val Sim Loss after epoch: 2.2168/3.4977
# EPOCH 63:
#  Avg. train loss/batch after 10 batches = 2.1956
#  Avg. train loss/batch after 20 batches = 2.2293
#  Avg. train loss/batch after 30 batches = 2.1801
#  Avg. train loss/batch after 40 batches = 2.1894
# Train/Val Sim Loss after epoch: 2.1894/3.5662
# EPOCH 64:
#  Avg. train loss/batch after 10 batches = 2.1765
#  Avg. train loss/batch after 20 batches = 2.1821
#  Avg. train loss/batch after 30 batches = 2.1823
#  Avg. train loss/batch after 40 batches = 2.1978
# Train/Val Sim Loss after epoch: 2.1978/3.6431
# EPOCH 65:
#  Avg. train loss/batch after 10 batches = 2.1912
#  Avg. train loss/batch after 20 batches = 2.1978
#  Avg. train loss/batch after 30 batches = 2.1726
#  Avg. train loss/batch after 40 batches = 2.1822
# Train/Val Sim Loss after epoch: 2.1822/3.5002
# EPOCH 66:
#  Avg. train loss/batch after 10 batches = 2.1827
#  Avg. train loss/batch after 20 batches = 2.1906
#  Avg. train loss/batch after 30 batches = 2.2130
#  Avg. train loss/batch after 40 batches = 2.1847
# Train/Val Sim Loss after epoch: 2.1847/3.6097
# EPOCH 67:
#  Avg. train loss/batch after 10 batches = 2.1624
#  Avg. train loss/batch after 20 batches = 2.1673
#  Avg. train loss/batch after 30 batches = 2.1910
#  Avg. train loss/batch after 40 batches = 2.1792
# Train/Val Sim Loss after epoch: 2.1792/3.6676
# EPOCH 68:
#  Avg. train loss/batch after 10 batches = 2.1756
#  Avg. train loss/batch after 20 batches = 2.1799
#  Avg. train loss/batch after 30 batches = 2.1690
#  Avg. train loss/batch after 40 batches = 2.1455
# Train/Val Sim Loss after epoch: 2.1455/3.6323
# EPOCH 69:
#  Avg. train loss/batch after 10 batches = 2.1725
#  Avg. train loss/batch after 20 batches = 2.1749
#  Avg. train loss/batch after 30 batches = 2.1686
#  Avg. train loss/batch after 40 batches = 2.1592
# Train/Val Sim Loss after epoch: 2.1592/3.6204
# EPOCH 70:
#  Avg. train loss/batch after 10 batches = 2.1662
#  Avg. train loss/batch after 20 batches = 2.1694
#  Avg. train loss/batch after 30 batches = 2.1518
#  Avg. train loss/batch after 40 batches = 2.1756
# Train/Val Sim Loss after epoch: 2.1756/3.5399
# EPOCH 71:
#  Avg. train loss/batch after 10 batches = 2.1490
#  Avg. train loss/batch after 20 batches = 2.1511
#  Avg. train loss/batch after 30 batches = 2.1567
#  Avg. train loss/batch after 40 batches = 2.1403
# Train/Val Sim Loss after epoch: 2.1403/3.5707
# EPOCH 72:
#  Avg. train loss/batch after 10 batches = 2.1492
#  Avg. train loss/batch after 20 batches = 2.1485
#  Avg. train loss/batch after 30 batches = 2.1596
#  Avg. train loss/batch after 40 batches = 2.1706
# Train/Val Sim Loss after epoch: 2.1706/3.7802
# EPOCH 73:
#  Avg. train loss/batch after 10 batches = 2.1502
#  Avg. train loss/batch after 20 batches = 2.1480
#  Avg. train loss/batch after 30 batches = 2.1299
#  Avg. train loss/batch after 40 batches = 2.1301
# Train/Val Sim Loss after epoch: 2.1301/3.5172
# EPOCH 74:
#  Avg. train loss/batch after 10 batches = 2.1302
#  Avg. train loss/batch after 20 batches = 2.1166
#  Avg. train loss/batch after 30 batches = 2.0998
#  Avg. train loss/batch after 40 batches = 2.1142
# Train/Val Sim Loss after epoch: 2.1142/3.6175
# EPOCH 75:
#  Avg. train loss/batch after 10 batches = 2.1074
#  Avg. train loss/batch after 20 batches = 2.1371
#  Avg. train loss/batch after 30 batches = 2.1142
#  Avg. train loss/batch after 40 batches = 2.1030
# Train/Val Sim Loss after epoch: 2.1030/3.5532
# EPOCH 76:
#  Avg. train loss/batch after 10 batches = 2.1060
#  Avg. train loss/batch after 20 batches = 2.1168
#  Avg. train loss/batch after 30 batches = 2.1098
#  Avg. train loss/batch after 40 batches = 2.0860
# Train/Val Sim Loss after epoch: 2.0860/3.6619
# EPOCH 77:
#  Avg. train loss/batch after 10 batches = 2.0998
#  Avg. train loss/batch after 20 batches = 2.0934
#  Avg. train loss/batch after 30 batches = 2.0994
#  Avg. train loss/batch after 40 batches = 2.1045
# Train/Val Sim Loss after epoch: 2.1045/3.5654
# EPOCH 78:
#  Avg. train loss/batch after 10 batches = 2.1077
#  Avg. train loss/batch after 20 batches = 2.0976
#  Avg. train loss/batch after 30 batches = 2.0976
#  Avg. train loss/batch after 40 batches = 2.0745
# Train/Val Sim Loss after epoch: 2.0745/3.4575
# EPOCH 79:
#  Avg. train loss/batch after 10 batches = 2.0954
#  Avg. train loss/batch after 20 batches = 2.0794
#  Avg. train loss/batch after 30 batches = 2.1257
#  Avg. train loss/batch after 40 batches = 2.0815
# Train/Val Sim Loss after epoch: 2.0815/3.4523
# EPOCH 80:
#  Avg. train loss/batch after 10 batches = 2.0816
#  Avg. train loss/batch after 20 batches = 2.0934
#  Avg. train loss/batch after 30 batches = 2.0999
#  Avg. train loss/batch after 40 batches = 2.1045
# Train/Val Sim Loss after epoch: 2.1045/3.6137
# EPOCH 81:
#  Avg. train loss/batch after 10 batches = 2.0820
#  Avg. train loss/batch after 20 batches = 2.0970
#  Avg. train loss/batch after 30 batches = 2.1064
#  Avg. train loss/batch after 40 batches = 2.1112
# Train/Val Sim Loss after epoch: 2.1112/3.6523
# EPOCH 82:
#  Avg. train loss/batch after 10 batches = 2.0801
#  Avg. train loss/batch after 20 batches = 2.0918
#  Avg. train loss/batch after 30 batches = 2.0589
#  Avg. train loss/batch after 40 batches = 2.0818
# Train/Val Sim Loss after epoch: 2.0818/3.4205
# EPOCH 83:
#  Avg. train loss/batch after 10 batches = 2.0625
#  Avg. train loss/batch after 20 batches = 2.0709
#  Avg. train loss/batch after 30 batches = 2.0675
#  Avg. train loss/batch after 40 batches = 2.0825
# Train/Val Sim Loss after epoch: 2.0825/3.5751
# EPOCH 84:
#  Avg. train loss/batch after 10 batches = 2.0767
#  Avg. train loss/batch after 20 batches = 2.0682
#  Avg. train loss/batch after 30 batches = 2.0772
#  Avg. train loss/batch after 40 batches = 2.0597
# Train/Val Sim Loss after epoch: 2.0597/3.4428
# EPOCH 85:
#  Avg. train loss/batch after 10 batches = 2.0509
#  Avg. train loss/batch after 20 batches = 2.0836
#  Avg. train loss/batch after 30 batches = 2.0595
#  Avg. train loss/batch after 40 batches = 2.0821
# Train/Val Sim Loss after epoch: 2.0821/3.8536
# EPOCH 86:
#  Avg. train loss/batch after 10 batches = 2.0739
#  Avg. train loss/batch after 20 batches = 2.0481
#  Avg. train loss/batch after 30 batches = 2.0507
#  Avg. train loss/batch after 40 batches = 2.0751
# Train/Val Sim Loss after epoch: 2.0751/3.5201
# EPOCH 87:
#  Avg. train loss/batch after 10 batches = 2.0598
#  Avg. train loss/batch after 20 batches = 2.0628
#  Avg. train loss/batch after 30 batches = 2.0465
#  Avg. train loss/batch after 40 batches = 2.0725
# Train/Val Sim Loss after epoch: 2.0725/3.5964
# EPOCH 88:
#  Avg. train loss/batch after 10 batches = 2.0617
#  Avg. train loss/batch after 20 batches = 2.0484
#  Avg. train loss/batch after 30 batches = 2.0356
#  Avg. train loss/batch after 40 batches = 2.0719
# Train/Val Sim Loss after epoch: 2.0719/3.4747
# EPOCH 89:
#  Avg. train loss/batch after 10 batches = 2.0482
#  Avg. train loss/batch after 20 batches = 2.0471
#  Avg. train loss/batch after 30 batches = 2.0427
#  Avg. train loss/batch after 40 batches = 2.0790
# Train/Val Sim Loss after epoch: 2.0790/3.4788
# EPOCH 90:
#  Avg. train loss/batch after 10 batches = 2.0609
#  Avg. train loss/batch after 20 batches = 2.0520
#  Avg. train loss/batch after 30 batches = 2.0684
#  Avg. train loss/batch after 40 batches = 2.0431
# Train/Val Sim Loss after epoch: 2.0431/3.4075
# EPOCH 91:
#  Avg. train loss/batch after 10 batches = 2.0589
#  Avg. train loss/batch after 20 batches = 2.0578
#  Avg. train loss/batch after 30 batches = 2.0314
#  Avg. train loss/batch after 40 batches = 2.0552
# Train/Val Sim Loss after epoch: 2.0552/3.4493
# EPOCH 92:
#  Avg. train loss/batch after 10 batches = 2.0714
#  Avg. train loss/batch after 20 batches = 2.0249
#  Avg. train loss/batch after 30 batches = 2.0251
#  Avg. train loss/batch after 40 batches = 2.0603
# Train/Val Sim Loss after epoch: 2.0603/3.6643
# EPOCH 93:
#  Avg. train loss/batch after 10 batches = 2.0188
#  Avg. train loss/batch after 20 batches = 2.0129
#  Avg. train loss/batch after 30 batches = 2.0448
#  Avg. train loss/batch after 40 batches = 2.0279
# Train/Val Sim Loss after epoch: 2.0279/3.6012
# EPOCH 94:
#  Avg. train loss/batch after 10 batches = 2.0119
#  Avg. train loss/batch after 20 batches = 2.0004
#  Avg. train loss/batch after 30 batches = 2.0284
#  Avg. train loss/batch after 40 batches = 1.9886
# Train/Val Sim Loss after epoch: 1.9886/3.5952
# EPOCH 95:
#  Avg. train loss/batch after 10 batches = 2.0065
#  Avg. train loss/batch after 20 batches = 2.0037
#  Avg. train loss/batch after 30 batches = 1.9966
#  Avg. train loss/batch after 40 batches = 2.0079
# Train/Val Sim Loss after epoch: 2.0079/3.7101
# EPOCH 96:
#  Avg. train loss/batch after 10 batches = 2.0163
#  Avg. train loss/batch after 20 batches = 2.0121
#  Avg. train loss/batch after 30 batches = 2.0077
#  Avg. train loss/batch after 40 batches = 2.0051
# Train/Val Sim Loss after epoch: 2.0051/3.6151
# EPOCH 97:
#  Avg. train loss/batch after 10 batches = 1.9979
#  Avg. train loss/batch after 20 batches = 2.0036
#  Avg. train loss/batch after 30 batches = 1.9942
#  Avg. train loss/batch after 40 batches = 2.0076
# Train/Val Sim Loss after epoch: 2.0076/3.4606
# EPOCH 98:
#  Avg. train loss/batch after 10 batches = 1.9967
#  Avg. train loss/batch after 20 batches = 1.9815
#  Avg. train loss/batch after 30 batches = 1.9866
#  Avg. train loss/batch after 40 batches = 1.9758
# Train/Val Sim Loss after epoch: 1.9758/3.4486
# EPOCH 99:
#  Avg. train loss/batch after 10 batches = 1.9968
#  Avg. train loss/batch after 20 batches = 1.9785
#  Avg. train loss/batch after 30 batches = 1.9971
#  Avg. train loss/batch after 40 batches = 1.9836
# Train/Val Sim Loss after epoch: 1.9836/3.4531
# EPOCH 100:
#  Avg. train loss/batch after 10 batches = 2.0009
#  Avg. train loss/batch after 20 batches = 1.9748
#  Avg. train loss/batch after 30 batches = 2.0168
#  Avg. train loss/batch after 40 batches = 2.0011
# Train/Val Sim Loss after epoch: 2.0011/3.6831
# CPU times: user 25min 13s, sys: 30.9 s, total: 25min 44s
# Wall time: 10min 55s

# %% [markdown]
# ## See embedded space

# %%
similarity_embedding.train(False)

similarity_outputs_1 = []

for idx, (theta_test, data_test, data_test_orig) in enumerate(test_data):
    if not ((theta_test.T[0][1] < 0.2) and (theta_test.T[0][1] > 0.1)):
        continue
    with torch.no_grad():
        similarity_output = similarity_embedding(data_test)
    similarity_outputs_1.append(similarity_output.numpy())

similarity_outputs_2 = []

for idx, (theta_test, data_test, data_test_orig) in enumerate(test_data):
    if not ((theta_test.T[0][1] < 0.5) and (theta_test.T[0][1] > 0.4)):
        continue
    with torch.no_grad():
        similarity_output = similarity_embedding(data_test)
    similarity_outputs_2.append(similarity_output.numpy())

# similarity_outputs_1 = []

# for idx, (theta_test, data_test, data_test_orig) in enumerate(test_data):
#     if not ((theta_test.T[0][0] < 0.5) and (theta_test.T[0][0] > 0.2)):
#         continue
#     with torch.no_grad():
#         similarity_output = similarity_embedding(data_test)
#     similarity_outputs_1.append(similarity_output.numpy())

# similarity_outputs_2 = []

# for idx, (theta_test, data_test, data_test_orig) in enumerate(test_data):
#     if not ((theta_test.T[0][0] < 1.61) and (theta_test.T[0][0] > 1.49)):
#         continue
#     with torch.no_grad():
#         similarity_output = similarity_embedding(data_test)
#     similarity_outputs_2.append(similarity_output.numpy())

# %%
similarity_outputs_1 = np.array(similarity_outputs_1)
similarity_outputs_2 = np.array(similarity_outputs_2)

# %%
similarity_outputs_1.shape
# Out:
# (53, 30, 4)

# %% [markdown]
# ### See projections of different $\omega_0$ and $\beta$ values

# %%
import corner

figure = corner.corner(
    similarity_outputs_1.reshape((similarity_outputs_1.shape[0]*similarity_outputs_1.shape[1], 4)),
    quantiles=[0.16, 0.5, 0.84], color="C1"
)

figure = corner.corner(
    similarity_outputs_2.reshape((similarity_outputs_2.shape[0]*similarity_outputs_2.shape[1], 4)),
    quantiles=[0.16, 0.5, 0.84], fig=figure, color="C2"
)

# %% [markdown]
# # Freeze weights, used as embedding network in MAF

# %%
from nflows.distributions import StandardNormal
from nflows.flows import Flow
from nflows.transforms.autoregressive import MaskedAffineAutoregressiveTransform
from nflows.transforms import CompositeTransform, RandomPermutation

import nflows.utils as torchutils

# %%
num_transforms = 5
num_blocks = 4
hidden_features = 50

context_features = 4

base_dist = StandardNormal([3])

transforms = []
for _ in range(num_transforms):
    block = [
        MaskedAffineAutoregressiveTransform(
            features=3,  # 3-dim posterior
            hidden_features=hidden_features,
            context_features=context_features,
            num_blocks=num_blocks,
            activation=torch.tanh,
            use_batch_norm=False,
            use_residual_blocks=True,
            dropout_probability=0.01
        ),
        RandomPermutation(features=3)
    ]
    transforms += block

transform = CompositeTransform(transforms)

flow = Flow(transform, base_dist, similarity_embedding)

# %%
# flow_model_path = './sho_flow_model_cnn_embedding.pt'
# torch.save(flow.state_dict(), flow_model_path)
# flow.load_state_dict(torch.load(flow_model_path))

# %% [markdown]
# # Train/Validate

# %%
num_augmentations = 10

def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.

    for idx, val in enumerate(train_data_loader, 1):
        augmented_theta, augmented_data = val

        loss = 0
        for ii in range(num_augmentations):
            theta = augmented_theta[:,ii,:]
            data = augmented_data[:,ii,:]

            flow_loss = -flow.log_prob(theta, context=data).sum()

            optimizer.zero_grad()
            flow_loss.backward()
            optimizer.step()
            
            loss += flow_loss.item()

        running_loss += loss/num_augmentations
        if idx % 100 == 0:
            last_loss = running_loss / 100 # avg loss
            print(' Avg. train loss/batch after {} batches = {:.4f}'.format(idx, last_loss))
            tb_x = epoch_index * len(train_data_loader) + idx
            tb_writer.add_scalar('Flow Loss/train', last_loss, tb_x)
            tb_writer.flush()
            running_loss = 0.
    return last_loss


def val_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.

    for idx, val in enumerate(val_data_loader, 1):
        augmented_theta, augmented_data = val
        loss = 0
        for ii in range(num_augmentations):
            theta = augmented_theta[:,ii,:]
            data = augmented_data[:,ii,:]

            flow_loss = -flow.log_prob(theta, context=data).sum()
            loss += flow_loss.item()

        running_loss += loss/num_augmentations
        if idx % 50 == 0:
            last_loss = running_loss / 50
            tb_x = epoch_index * len(val_data_loader) + idx + 1
            tb_writer.add_scalar('Flow Loss/val', last_loss, tb_x)

            tb_writer.flush()
            running_loss = 0.
    tb_writer.flush()
    return last_loss

# %%
optimizer = optim.Adam(flow.parameters(), lr=1e-3)

scheduler_1 = optim.lr_scheduler.ConstantLR(optimizer, total_iters=5)
scheduler_2 = optim.lr_scheduler.OneCycleLR(optimizer, total_steps=20, max_lr=1e-3)
scheduler_3 = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20)

scheduler = optim.lr_scheduler.SequentialLR(
    optimizer, schedulers=[scheduler_1, scheduler_2, scheduler_3], milestones=[5, 20])

# %%
writer = SummaryWriter("sho_flow_conv_embedding", comment="With LR=1e-3", flush_secs=5)
epoch_number = 0

# %%
# %%time
# UNCOMMENT AND RUN TO TRAIN FROM SCRATCH
EPOCHS = 50

for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))
    # Gradient tracking
    flow.train(True)
    # flow._embedding_net.train(False)
    # no gradient tracking for embedding layer
    for name, param in flow._embedding_net.named_parameters():
        param.requires_grad = False

    avg_train_loss = train_one_epoch(epoch_number, writer)
    
    # no gradient tracking, for validation
    flow.train(False)
    avg_val_loss = val_one_epoch(epoch_number, writer)
    
    print(f"Train/Val flow Loss after epoch: {avg_train_loss:.4f}/{avg_val_loss:.4f}")

    epoch_number += 1
    scheduler.step()

# %% [markdown]
# # Check on test data

# %%
import pandas as pd

def cast_as_bilby_result(samples, truth):
    injections = dict.fromkeys(injection_parameters)
    injections['omega_0'] = float(truth.numpy()[0])
    injections['beta'] = float(truth.numpy()[1])

    posterior = dict.fromkeys(injection_parameters)
    samples_numpy = samples.numpy()
    posterior['omega_0'] = samples_numpy.T[0].flatten()
    posterior['beta'] = samples_numpy.T[1].flatten()
    posterior = pd.DataFrame(posterior)
    
    return bilby.result.Result(
        label="test_data",
        injection_parameters=injections,
        posterior=posterior,
        search_parameter_keys=list(injections.keys()),
        priors=priors
    )

# %% [markdown]
# ## Posterior

# %%
def live_plot_samples(samples, truth):
    clear_output(wait=True)
    sleep(1)
    figure = corner.corner(
        samples.numpy(), quantiles=[0.16, 0.5, 0.84],
        show_titles=True, labels=["omega_0", "beta", "shift"],
        truth=truth
    )

    corner.overplot_lines(figure, truth, color="C1")
    corner.overplot_points(figure, truth[None], marker="s", color="C1")

# %%
for idx, (theta_test, data_test) in enumerate(test_data):
    if idx % 10 !=0: continue 
    with torch.no_grad():
        samples = flow.sample(5000, context=data_test[0].reshape((1, 200)))
    live_plot_samples(samples[0], theta_test[0])
    plt.show()

# %%
theta_test[0]

# %% [markdown]
# # PP plot

# %%
results = []
for idx, (theta_test, data_test) in enumerate(test_data):
    with torch.no_grad():
        samples = flow.sample(3000, context=data_test[0].reshape((1, 200)))
    results.append(
        cast_as_bilby_result(samples, theta_test[0]))

import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    bilby.result.make_pp_plot(results, save=False, keys=['omega_0', 'beta'])
